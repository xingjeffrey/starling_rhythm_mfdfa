# %% [markdown]
# # 0.04 Examine Surrogate Data
# #### 09/12/2022, JX
# > Please show me data

# %%
from starling_rhythm.utils.paths import PROCESSED_DIR

# %%
import pandas as pd

# %%
SAVE_PATH = PROCESSED_DIR / 'starling_zenodo_2019_amp_envs_MF_IAAFT200_FULL.pickle'
ae_df = pd.read_pickle(SAVE_PATH)

# %%
ae_df
# Out:
#          bID                        wav_file  \
# 0      b1053  2017-11-13_16-29-28-410000.wav
# 1      b1053  2017-11-16_15-17-52-520000.wav
# 2      b1053  2017-11-20_14-15-32-360000.wav
# 3      b1053  2017-11-20_12-40-56-130000.wav
# 4      b1053  2017-11-15_15-30-01-000000.wav
# ...      ...                             ...
# 10495  b1145  2017-11-09_13-26-01-740000.wav
# 10496  b1145  2017-11-07_17-30-06-880000.wav
# 10497  b1145  2017-11-09_09-34-49-120000.wav
# 10498  b1145  2017-11-09_09-26-04-120000.wav
# 10499  b1145  2017-11-04_15-00-51-100000.wav
#
#                                                  amp_env  \
# 0      [0.009873399510979652, 0.015623422339558601, 0...
# 1      [0.0003380597336217761, 0.00034135428722947836...
# 2      [2.641892910003662, 2.6070051193237305, 2.5947...
# 3      [3.971318801632151e-05, 3.945435310015455e-05,...
# 4      [0.005851297173649073, 0.49159008264541626, 1....
# ...                                                  ...
# 10495  [0.0003850629145745188, 0.0003816374228335917,...
# 10496  [0.00022515977616421878, 0.0001997244544327259...
# 10497  [0.004488207399845123, 1.2879040241241455, 3.4...
# 10498  [0.00029243348399177194, 0.0002883640117943287...
# 10499  [0.0012021420989185572, 0.0012225217651575804,...
#
#                                                   h_expo  MF_range  \
# 0      [1.528071866963577, 1.0370111976118286, 0.8437...  1.011097
# 1      [1.1938116698829084, 1.0984076594608625, 1.032...  0.351719
# 2      [1.1806910145575205, 1.0637405119967855, 0.977...  0.426110
# 3      [1.1870676604975956, 1.0644852178050632, 0.983...  0.416832
# 4      [1.1330045795095076, 1.0547100658878008, 0.984...  0.376517
# ...                                                  ...       ...
# 10495  [1.180004894319496, 1.0197033102020214, 0.9132...  0.545500
# 10496  [1.2047430508822017, 1.0585859494621113, 0.943...  0.611907
# 10497  [1.28912933912076, 1.1004097813293756, 0.96728...  0.661470
# 10498  [1.260354642359515, 1.0466296263441792, 0.9064...  0.669632
# 10499  [1.294949268727799, 1.1245458403332544, 1.0228...  0.479904
#
#                                           mf_iaaft_range
# 0      [0.9276718685714906, 0.9171483752163467, 0.944...
# 1      [0.28812645556733407, 0.3255784330799333, 0.31...
# 2      [0.3144035067800034, 0.2852736875864027, 0.317...
# 3      [0.30861717466345995, 0.28864976695326583, 0.3...
# 4      [0.3876441965284274, 0.3354107561595341, 0.246...
# ...                                                  ...
# 10495  [0.3514270190757175, 0.32709049219820485, 0.37...
# 10496  [0.5688644655873416, 0.44159948357619083, 0.41...
# 10497  [0.45379276220452824, 0.3641418002581174, 0.41...
# 10498  [0.4373893471223834, 0.4469140843113437, 0.474...
# 10499  [0.3309944898989228, 0.36419105154769316, 0.34...
#
# [10499 rows x 6 columns]

# %% [markdown]
# ## Parse t-statistics

# %%
import scipy.stats as stats
import numpy as np

# %%
ts = []
p = []
for MF_range, mf_iaaft_range in zip(ae_df['MF_range'].values, ae_df['mf_iaaft_range']):
    test = stats.ttest_1samp(mf_iaaft_range, MF_range)
    ts.append(test[0])
    p.append(test[1])
    
ae_df['ts'] = ts
ae_df['p'] = p

# %%
import statsmodels.stats.multitest

# %%
bonferroni = statsmodels.stats.multitest.multipletests(ae_df['p'].values, alpha = 0.05, method = 'bonferroni')
ae_df['sig'] = bonferroni[0]
ae_df['bonf_p'] = bonferroni[1]

# %%
ae_df.head()
# Out:
#      bID                        wav_file  \
# 0  b1053  2017-11-13_16-29-28-410000.wav
# 1  b1053  2017-11-16_15-17-52-520000.wav
# 2  b1053  2017-11-20_14-15-32-360000.wav
# 3  b1053  2017-11-20_12-40-56-130000.wav
# 4  b1053  2017-11-15_15-30-01-000000.wav
#
#                                              amp_env  \
# 0  [0.009873399510979652, 0.015623422339558601, 0...
# 1  [0.0003380597336217761, 0.00034135428722947836...
# 2  [2.641892910003662, 2.6070051193237305, 2.5947...
# 3  [3.971318801632151e-05, 3.945435310015455e-05,...
# 4  [0.005851297173649073, 0.49159008264541626, 1....
#
#                                               h_expo  MF_range  \
# 0  [1.528071866963577, 1.0370111976118286, 0.8437...  1.011097
# 1  [1.1938116698829084, 1.0984076594608625, 1.032...  0.351719
# 2  [1.1806910145575205, 1.0637405119967855, 0.977...  0.426110
# 3  [1.1870676604975956, 1.0644852178050632, 0.983...  0.416832
# 4  [1.1330045795095076, 1.0547100658878008, 0.984...  0.376517
#
#                                       mf_iaaft_range         ts             p  \
# 0  [0.9276718685714906, 0.9171483752163467, 0.944... -15.573756  3.307088e-16
# 1  [0.28812645556733407, 0.3255784330799333, 0.31... -13.877060  7.641647e-15
# 2  [0.3144035067800034, 0.2852736875864027, 0.317... -28.399127  9.336860e-24
# 3  [0.30861717466345995, 0.28864976695326583, 0.3... -28.056127  1.342316e-23
# 4  [0.3876441965284274, 0.3354107561595341, 0.246...  -9.375222  1.461871e-10
#
#     sig        bonf_p
# 0  True  3.472112e-12
# 1  True  8.022965e-11
# 2  True  9.802769e-20
# 3  True  1.409298e-19
# 4  True  1.534819e-06

# %% [markdown]
# ## t-statistic inquiries

# %%
## plot shuffle against shuffle

# %%
### Out of 10499 bouts, how many are significantly multifractal?
np.unique(ae_df['sig'].values, return_counts = True)
# Out:
# (array([False,  True]), array([  137, 10362]))

# %%
### distribution?
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

plt.rcParams['patch.edgecolor'] = 'none'
figure(figsize = (16, 6), dpi = 300)
sns.set_style('ticks')

sns.histplot(data = ae_df, x = 'ts', stat = 'density', color = 'black', fill = 'black')
# Out:
# <AxesSubplot:xlabel='ts', ylabel='Density'>

# %%
### distribution?
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

plt.rcParams['patch.edgecolor'] = 'none'
figure(figsize = (16, 6), dpi = 300)
sns.set_style('ticks')

sns.histplot(data = ae_df, x = 'ts', stat = 'density', hue = 'bID', color = 'bID', alpha = 0.25, kde = True)
# Out:
# <AxesSubplot:xlabel='ts', ylabel='Density'>

# %% [markdown]
# ## Rank Order

# %%
bird_average = []

for bID in np.unique(ae_df['bID'].values):
    subframe = ae_df[ae_df['bID'] == bID]
    bird_average.append([np.mean(subframe['ts']), bID])

# %%
bird_average.sort()
bird_average
# Out:
# [[-31.443030913661907, 'b1143'],
#  [-30.428177482154993, 'b1076'],
#  [-28.156698046285456, 'b1077'],
#  [-28.04865068072689, 'b1125'],
#  [-26.68926969018661, 'b1066'],
#  [-26.381925458785137, 'b1145'],
#  [-24.893645088619216, 'b1060'],
#  [-24.20041542812753, 'b1053'],
#  [-24.037205885067344, 'b1159'],
#  [-21.935393877378505, 'B338'],
#  [-20.620542071515537, 'b1160'],
#  [-19.83798373187222, 'B335'],
#  [-17.957351476266194, 'B337'],
#  [-17.40473464079037, 'B336']]

# %% [markdown]
# ## Pull out three cohorts: monofractal, low multifractal, high multifractal

# %% [markdown]
# ### mono

# %%
mono = ae_df[ae_df['sig'] == False]

# %%
np.unique(mono['bID'].values, return_counts = True)
# Out:
# (array(['B335', 'B336', 'B337', 'B338', 'b1060', 'b1066', 'b1077', 'b1145',
#         'b1159', 'b1160'], dtype=object),
#  array([61, 34, 14, 10,  1,  2,  1,  3,  1, 10]))

# %%
np.mean(mono.ts)
# Out:
# -3.9364605969113557

# %%
mono_selected = mono.sort_values(by = 'ts', ascending=False)[:10]

# %%
mono_selected
# Out:
#        bID                        wav_file  \
# 6862  B335  2008-06-03_05-17-00-000000.wav
# 6004  B335  2008-06-18_05-54-00-000000.wav
# 9804  B336  2008-06-30_12-14-00-000000.wav
# 9653  B336  2008-07-03_07-13-00-000000.wav
# 5861  B335  2008-06-05_07-06-00-000000.wav
# 7171  B335  2008-06-10_01-48-00-000000.wav
# 5734  B335  2008-06-13_04-43-00-000000.wav
# 5987  B335  2008-05-09_16-07-00-000000.wav
# 9658  B336  2008-06-09_21-48-00-000000.wav
# 5830  B335  2008-06-16_00-59-00-000000.wav
#
#                                                 amp_env  \
# 6862  [0.0002483963326085359, 0.13896213471889496, 0...
# 6004  [0.0020253732800483704, 1.2484756708145142, 3....
# 9804  [0.5741668343544006, 0.8141220808029175, 0.885...
# 9653  [2.958448886871338, 2.2301368713378906, 1.9980...
# 5861  [0.4747650921344757, 0.7139626741409302, 0.917...
# 7171  [2.387779712677002, 3.147059440612793, 3.94631...
# 5734  [0.3868618607521057, 0.31490761041641235, 0.17...
# 5987  [0.00039131889934651554, 0.2830059826374054, 0...
# 9658  [2.9336252212524414, 2.9727210998535156, 3.200...
# 5830  [0.00946671050041914, 3.0352940559387207, 5.84...
#
#                                                  h_expo  MF_range  \
# 6862  [1.0218516404905311, 0.9467228504976248, 0.894...  0.322541
# 6004  [1.0942529014205076, 0.9979940956181037, 0.930...  0.355692
# 9804  [1.1609626665214963, 1.0799021002757516, 1.029...  0.277422
# 9653  [1.133241948010946, 1.0685082019417627, 1.0184...  0.291733
# 5861  [1.151847335999829, 1.0760182931100328, 1.0231...  0.300361
# 7171  [1.134506833379174, 1.0468093533462506, 0.9857...  0.321187
# 5734  [1.1619598054762115, 1.0634213504701162, 1.005...  0.324925
# 5987  [1.1507733245844078, 1.089061782759079, 1.0397...  0.337943
# 49    [0.006683799438178539, 0.012148234061896801, 0...
# 1529  [0.0004550936573650688, 0.016606248915195465, ...
#
#                                                  h_expo  MF_range  \
# 4164  [1.6194667129136129, 1.1366950408595555, 0.916...  1.048649
# 7316  [1.503021826562428, 0.9989996935754197, 0.7945...  1.023758
# 685   [1.4823352166566166, 1.1191816020959133, 0.892...  1.002034
# 8728  [1.2144124926736115, 0.9430676768027468, 0.791...  0.728977
# 1692  [1.4718651939548164, 1.2035661344374105, 1.045...  0.817233
# 1030  [1.4610345129162525, 1.1968041817894952, 1.035...  0.768272
# 6195  [1.3030027100377315, 1.0850165971590893, 0.973...  0.556878
# 938   [1.3973817817133294, 1.0578087057859902, 0.872...  0.854927
# 49    [1.5790068800923092, 1.1261156917571582, 0.924...  0.987078
# 1529  [1.5294456565387495, 1.2177181618619946, 1.041...  0.892722
#
#                                          mf_iaaft_range          ts  \
# 4164  [0.8848697402364974, 0.8792390841055108, 0.881... -119.438867
# 7316  [0.9268247734922783, 0.928916975906718, 0.9366... -108.588023
# 685   [0.6232592953369991, 0.6060521045559293, 0.626...  -96.403793
# 8728  [0.554427466393414, 0.5792396106872203, 0.5727...  -95.543326
# 1692  [0.5125969849811212, 0.4951791152320676, 0.479...  -92.431401
# 1030  [0.4386532798150551, 0.4880056827326048, 0.460...  -90.692328
# 6195  [0.35509593530132666, 0.3346268974497739, 0.33...  -90.652249
# 938   [0.654836060231019, 0.6564616609453336, 0.6381...  -87.510296
# 49    [0.7377125594701519, 0.6875694995195175, 0.699...  -87.050019
# 1529  [0.6934305488384422, 0.6921913378095262, 0.676...  -85.323717
#
#                  p   sig        bonf_p    t_rank
# 4164  7.297571e-43  True  7.661720e-39  0.000097
# 7316  1.388306e-41  True  1.457582e-37  0.000193
# 685   5.498051e-40  True  5.772404e-36  0.000290
# 8728  7.253086e-40  True  7.615015e-36  0.000386
# 1692  2.017511e-39  True  2.118185e-35  0.000483
# 1030  3.627611e-39  True  3.808629e-35  0.000579
# 6195  3.677477e-39  True  3.860984e-35  0.000676
# 938   1.093099e-38  True  1.147644e-34  0.000772
# 49    1.286409e-38  True  1.350601e-34  0.000869
# 1529  2.387615e-38  True  2.506757e-34  0.000965

# %% [markdown]
# ### Save to a directory

# %%
from starling_rhythm.utils.paths import DATA_DIR
from pathlib import Path
from glob import glob

# %%
mono_wav_paths = []
MF_low_wav_paths = []
MF_mid_wav_paths = []
MF_high_wav_paths = []

for wav in mono_selected.wav_file.values:
    mono_wav_paths.append(list(Path(DATA_DIR).rglob(wav))[0])
    
for wav in MF_low_selected.wav_file.values:
    MF_low_wav_paths.append(list(Path(DATA_DIR).rglob(wav))[0])
    
for wav in MF_mid_selected.wav_file.values:
    MF_mid_wav_paths.append(list(Path(DATA_DIR).rglob(wav))[0])

for wav in MF_high_selected.wav_file.values:
    MF_high_wav_paths.append(list(Path(DATA_DIR).rglob(wav))[0])

# %%
import scipy
from starling_rhythm.utils.paths import ensure_dir, PROJECT_DIR

# %%
AUDIO_PATH = PROJECT_DIR / 'data' / 'raw'

# %%
for wav in mono_wav_paths:
    rate, data = scipy.io.wavfile.read(wav)
    split_path = str(wav).split('/')
    filename = split_path[-1]
    filename = AUDIO_PATH / 'mono' / filename
    ensure_dir(filename)
    scipy.io.wavfile.write(filename = filename, data = data, rate = rate)
    
for wav in MF_low_wav_paths:
    rate, data = scipy.io.wavfile.read(wav)
    split_path = str(wav).split('/')
    filename = split_path[-1]
    filename = AUDIO_PATH / 'low_MF' / filename
    ensure_dir(filename)
    scipy.io.wavfile.write(filename = filename, data = data, rate = rate)
    
for wav in MF_mid_wav_paths:
    rate, data = scipy.io.wavfile.read(wav)
    split_path = str(wav).split('/')
    filename = split_path[-1]
    filename = AUDIO_PATH / 'mid_MF' / filename
    ensure_dir(filename)
    scipy.io.wavfile.write(filename = filename, data = data, rate = rate)
    
for wav in MF_high_wav_paths:
    rate, data = scipy.io.wavfile.read(wav)
    split_path = str(wav).split('/')
    filename = split_path[-1]
    filename = AUDIO_PATH / 'high_MF' / filename
    ensure_dir(filename)
    scipy.io.wavfile.write(filename = filename, data = data, rate = rate)

# %% [markdown]
# ## Is t correlated with bout length? repertoire size of the bout (of the bird?)

# %%
lens = []
for amp_env in ae_df.amp_env:
    lens.append(len(amp_env))
    
ae_df['ae_len'] = lens

# %%
ae_df.head()
# Out:
#      bID                        wav_file  \
# 0  b1053  2017-11-13_16-29-28-410000.wav
# 1  b1053  2017-11-16_15-17-52-520000.wav
# 2  b1053  2017-11-20_14-15-32-360000.wav
# 3  b1053  2017-11-20_12-40-56-130000.wav
# 4  b1053  2017-11-15_15-30-01-000000.wav
#
#                                              amp_env  \
# 0  [0.009873399510979652, 0.015623422339558601, 0...
# 1  [0.0003380597336217761, 0.00034135428722947836...
# 2  [2.641892910003662, 2.6070051193237305, 2.5947...
# 3  [3.971318801632151e-05, 3.945435310015455e-05,...
# 4  [0.005851297173649073, 0.49159008264541626, 1....
#
#                                               h_expo  MF_range  \
# 0  [1.528071866963577, 1.0370111976118286, 0.8437...  1.011097
# 1  [1.1938116698829084, 1.0984076594608625, 1.032...  0.351719
# 2  [1.1806910145575205, 1.0637405119967855, 0.977...  0.426110
# 3  [1.1870676604975956, 1.0644852178050632, 0.983...  0.416832
# 4  [1.1330045795095076, 1.0547100658878008, 0.984...  0.376517
#
#                                       mf_iaaft_range         ts             p  \
# 0  [0.9276718685714906, 0.9171483752163467, 0.944... -15.573756  3.307088e-16
# 1  [0.28812645556733407, 0.3255784330799333, 0.31... -13.877060  7.641647e-15
# 2  [0.3144035067800034, 0.2852736875864027, 0.317... -28.399127  9.336860e-24
# 3  [0.30861717466345995, 0.28864976695326583, 0.3... -28.056127  1.342316e-23
# 4  [0.3876441965284274, 0.3354107561595341, 0.246...  -9.375222  1.461871e-10
#
#     sig        bonf_p  ae_len
# 0  True  3.472112e-12    4730
# 1  True  8.022965e-11   10866
# 2  True  9.802769e-20   11172
# 3  True  1.409298e-19   25480
# 4  True  1.534819e-06    9318

# %%
sns.scatterplot(data = ae_df, x = 'ae_len', y = 'ts', size = 0.0005)
## if len goes up, ts should go down?
## this is roughly the case
# Out:
# <AxesSubplot:xlabel='ae_len', ylabel='ts'>

# %%
ae_335 = ae_df[ae_df['bID'] == 'B336']

# %%
### Out of 10499 bouts, how many are significantly multifractal?
np.unique(ae_335['sig'].values, return_counts = True)
# Out:
# (array([False,  True]), array([ 34, 329]))

# %%
sns.scatterplot(data = ae_335, x = 'ae_len', y = 'ts', size = 0.0005)
## if len goes up, ts should go down?
## this is roughly the case
# Out:
# <AxesSubplot:xlabel='ae_len', ylabel='ts'>

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
md = smf.mixedlm('ae_len ~ ts', ae_df, groups = ae_df['bID'])

# %%
mdf = md.fit()
# Out:
# /home/AD/j8xing/anaconda3/envs/starling_rhythm/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/AD/j8xing/anaconda3/envs/starling_rhythm/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(

# %%
print(mdf.summary())
# Out:
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:             MixedLM  Dependent Variable:  ae_len
# No. Observations:  10499    Method:              REML
# No. Groups:        14       Scale:               11016702.6619
# Min. group size:   223      Log-Likelihood:      -100040.9643
# Max. group size:   1939     Converged:           Yes
# Mean group size:   749.9
# --------------------------------------------------------------
#              Coef.    Std.Err.    z    P>|z|  [0.025   0.975]
# --------------------------------------------------------------
# Intercept    6335.986  393.603  16.097 0.000 5564.539 7107.434
# ts            -50.101    3.150 -15.906 0.000  -56.274  -43.927
# Group Var 2063882.981  321.710
# ==============================================================

# %%
## filter so that only certain lengths can come through (~20 seconds / 4000 points with 200 SR)

# %%
ae_335 = ae_335[(ae_335['ae_len'] > 3750) & (ae_335['ae_len'] < 4250)]

# %%
mono_335 = ae_335[ae_335['sig'] == False].sort_values(by = 'ts', ascending = False)[0:6]
high_335 = ae_335[ae_335['sig'] == True].sort_values(by = 'ts', ascending = True)[0:6]

# %%
ae_335['t_rank'] = ae_335['ts'].rank(pct = True)

# %%
mid_335 = ae_335[(ae_335['t_rank'] > 0.05) & (ae_335['t_rank'] < 0.1)].sort_values(by = 'ts', ascending = True)[:10]

# %%
# save

# %%
mono335_wav_paths = []
mid335_wav_paths = []
high335_wav_paths = []

for wav in mono_335.wav_file.values:
    mono335_wav_paths.append(list(Path(DATA_DIR).rglob(wav))[0])
    
for wav in mid_335.wav_file.values:
    mid335_wav_paths.append(list(Path(DATA_DIR).rglob(wav))[0])

for wav in high_335.wav_file.values:
    high335_wav_paths.append(list(Path(DATA_DIR).rglob(wav))[0])

# %%
from starling_rhythm.utils.audio import compact_support

# %%
def save_stim(paths, foldernames = 'default'):
    for wav in paths:
        rate, data = scipy.io.wavfile.read(wav)
        
        ## do the same trimming procedure
        data = compact_support(data, stds = 1, buffer = 100)
        
        split_path = str(wav).split('/')
        filename = split_path[-1]
        filename = AUDIO_PATH / foldernames / filename
        ensure_dir(filename)
        scipy.io.wavfile.write(filename = filename, data = data, rate = rate)

# %%
for paths, foldernames in zip(
    [mono335_wav_paths, mid335_wav_paths, high335_wav_paths], 
    ['mono335', 'mid335', 'high335']
):
    save_stim(paths, foldernames)
